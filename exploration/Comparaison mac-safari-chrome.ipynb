# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img_1 = Image.open('./seed_723_timestamp_1551476835.jpg')

# %%
img_2 = Image.open('./seed_723_timestamp_1551477405.jpg')

# %%
plt.imshow(np.array(img_1) - np.array(img_2))

# %%
img_2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x11AD62A90>
